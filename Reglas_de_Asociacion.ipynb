# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import seaborn as sns

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
bread_basket_data = pd.read_csv('/content/BreadBasket_DMS.csv')

bread_basket_data.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          Date      Time  Transaction           Item
# 0  2016-10-30  09:58:11            1          Bread
# 1  2016-10-30  10:05:34            2   Scandinavian
# 2  2016-10-30  10:05:34            2   Scandinavian
# 3  2016-10-30  10:07:57            3  Hot chocolate
# 4  2016-10-30  10:07:57            3            Jam
# 5  2016-10-30  10:07:57            3        Cookies
# 6  2016-10-30  10:08:41            4         Muffin
# 7  2016-10-30  10:13:03            5         Coffee
# 8  2016-10-30  10:13:03            5         Pastry
# 9  2016-10-30  10:13:03            5          Bread
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Transaction'].plot(kind='hist', bins=20, title='Transaction')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Time').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('Item').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Date']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Date'}, axis=1)
#               .sort_values('Date', ascending=True))
#   xs = counted['Date']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_3.sort_values('Date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Time')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Time', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Date')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Date']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Date'}, axis=1)
#               .sort_values('Date', ascending=True))
#   xs = counted['Date']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_4.sort_values('Date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Item')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Item', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Date')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Time']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Time'}, axis=1)
#               .sort_values('Time', ascending=True))
#   xs = counted['Time']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('Time', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Time')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Time', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Time')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Time']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Time'}, axis=1)
#               .sort_values('Time', ascending=True))
#   xs = counted['Time']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_6.sort_values('Time', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Item')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Item', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Time')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7['Transaction'].plot(kind='line', figsize=(8, 4), title='Transaction')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Item'].value_counts()
#     for x_label, grp in _df_8.groupby('Time')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Time')
# _ = plt.ylabel('Item')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_9['Time'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_9, x='Transaction', y='Time', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_10['Item'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_10, x='Transaction', y='Item', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
bread_basket_data.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (21293, 4)

# %%
bread_basket_data.loc[bread_basket_data['Item'] == 'NONE'].count()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Date           786
# Time           786
# Transaction    786
# Item           786
# dtype: int64

# %%
bread_basket_data = bread_basket_data.drop(
    bread_basket_data.loc[bread_basket_data['Item'] == 'NONE'].index)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
bread_basket_data.loc[bread_basket_data['Item'] == 'NONE'].count()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Date           0
# Time           0
# Transaction    0
# Item           0
# dtype: int64

# %%
bread_basket_data.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (20507, 4)

# %%
bread_basket_data['Item'].unique()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['Bread', 'Scandinavian', 'Hot chocolate', 'Jam', 'Cookies',
#        'Muffin', 'Coffee', 'Pastry', 'Medialuna', 'Tea', 'Tartine',
#        'Basket', 'Mineral water', 'Farm House', 'Fudge', 'Juice',
#        "Ella's Kitchen Pouches", 'Victorian Sponge', 'Frittata',
#        'Hearty & Seasonal', 'Soup', 'Pick and Mix Bowls', 'Smoothies',
#        'Cake', 'Mighty Protein', 'Chicken sand', 'Coke',
#        'My-5 Fruit Shoot', 'Focaccia', 'Sandwich', 'Alfajores', 'Eggs',
#        'Brownie', 'Dulce de Leche', 'Honey', 'The BART', 'Granola',
#        'Fairy Doors', 'Empanadas', 'Keeping It Local', 'Art Tray',
#        'Bowl Nic Pitt', 'Bread Pudding', 'Adjustment', 'Truffles',
#        'Chimichurri Oil', 'Bacon', 'Spread', 'Kids biscuit', 'Siblings',
#        'Caramel bites', 'Jammie Dodgers', 'Tiffin', 'Olum & polenta',
#        'Polenta', 'The Nomad', 'Hack the stack', 'Bakewell',
#        'Lemon and coconut', 'Toast', 'Scone', 'Crepes', 'Vegan mincepie',
#        'Bare Popcorn', 'Muesli', 'Crisps', 'Pintxos', 'Gingerbread syrup',
#        'Panatone', 'Brioche and salami', 'Afternoon with the baker',
#        'Salad', 'Chicken Stew', 'Spanish Brunch',
#        'Raspberry shortbread sandwich', 'Extra Salami or Feta',
#        'Duck egg', 'Baguette', "Valentine's card", 'Tshirt',
#        'Vegan Feast', 'Postcard', 'Nomad bag', 'Chocolates',
#        'Coffee granules ', 'Drinking chocolate spoons ',
#        'Christmas common', 'Argentina Night', 'Half slice Monster ',
#        'Gift voucher', 'Cherry me Dried fruit', 'Mortimer', 'Raw bars',
#        'Tacos/Fajita'], dtype=object)

# %%
basket_items = {}

for item in bread_basket_data['Item']:
    if item in basket_items:
        basket_items[item] = basket_items[item] + 1
    else:
        basket_items[item] = 1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
basket_items
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'Bread': 3325,
#  'Scandinavian': 277,
#  'Hot chocolate': 590,
#  'Jam': 149,
#  'Cookies': 540,
#  'Muffin': 370,
#  'Coffee': 5471,
#  'Pastry': 856,
#  'Medialuna': 616,
#  'Tea': 1435,
#  'Tartine': 47,
#  'Basket': 6,
#  'Mineral water': 136,
#  'Farm House': 374,
#  'Fudge': 159,
#  'Juice': 369,
#  "Ella's Kitchen Pouches": 17,
#  'Victorian Sponge': 7,
#  'Frittata': 81,
#  'Hearty & Seasonal': 107,
#  'Soup': 342,
#  'Pick and Mix Bowls': 12,
#  'Smoothies': 77,
#  'Cake': 1025,
#  'Mighty Protein': 11,
#  'Chicken sand': 1,
#  'Coke': 185,
#  'My-5 Fruit Shoot': 18,
#  'Focaccia': 54,
#  'Sandwich': 771,
#  'Alfajores': 369,
#  'Eggs': 28,
#  'Brownie': 379,
#  'Dulce de Leche': 13,
#  'Honey': 6,
#  'The BART': 1,
#  'Granola': 28,
#  'Fairy Doors': 2,
#  'Empanadas': 7,
#  'Keeping It Local': 63,
#  'Art Tray': 38,
#  'Bowl Nic Pitt': 2,
#  'Bread Pudding': 4,
#  'Adjustment': 1,
#  'Truffles': 193,
#  'Chimichurri Oil': 2,
#  'Bacon': 1,
#  'Spread': 2,
#  'Kids biscuit': 12,
#  'Siblings': 2,
#  'Caramel bites': 3,
#  'Jammie Dodgers': 125,
#  'Tiffin': 146,
#  'Olum & polenta': 1,
#  'Polenta': 1,
#  'The Nomad': 58,
#  'Hack the stack': 2,
#  'Bakewell': 48,
#  'Lemon and coconut': 6,
#  'Toast': 318,
#  'Scone': 327,
#  'Crepes': 6,
#  'Vegan mincepie': 54,
#  'Bare Popcorn': 5,
#  'Muesli': 8,
#  'Crisps': 14,
#  'Pintxos': 6,
#  'Gingerbread syrup': 9,
#  'Panatone': 5,
#  'Brioche and salami': 3,
#  'Afternoon with the baker': 44,
#  'Salad': 99,
#  'Chicken Stew': 123,
#  'Spanish Brunch': 172,
#  'Raspberry shortbread sandwich': 3,
#  'Extra Salami or Feta': 38,
#  'Duck egg': 12,
#  'Baguette': 152,
#  "Valentine's card": 13,
#  'Tshirt': 21,
#  'Vegan Feast': 16,
#  'Postcard': 10,
#  'Nomad bag': 8,
#  'Chocolates': 10,
#  'Coffee granules ': 7,
#  'Drinking chocolate spoons ': 8,
#  'Christmas common': 11,
#  'Argentina Night': 7,
#  'Half slice Monster ': 6,
#  'Gift voucher': 1,
#  'Cherry me Dried fruit': 3,
#  'Mortimer': 5,
#  'Raw bars': 1,
#  'Tacos/Fajita': 11}

# %%
item_names = []
item_frequencies = []

for key, val in basket_items.items():
    item_names.append(key)
    item_frequencies.append(val)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
items_table = pd.DataFrame({'Names': item_names,
                            'Frequencies': item_frequencies})

items_table
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                     Names  Frequencies
# 0                   Bread         3325
# 1            Scandinavian          277
# 2           Hot chocolate          590
# 3                     Jam          149
# 4                 Cookies          540
# ..                    ...          ...
# 89           Gift voucher            1
# 90  Cherry me Dried fruit            3
# 91               Mortimer            5
# 92               Raw bars            1
# 93           Tacos/Fajita           11
#
# [94 rows x 2 columns]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['Frequencies'].plot(kind='hist', bins=20, title='Frequencies')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13.plot(kind='scatter', x='index', y='Frequencies', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Frequencies']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Frequencies')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_15.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['Frequencies'].plot(kind='line', figsize=(8, 4), title='Frequencies')
# plt.gca().spines[['top', 'right']].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from matplotlib import pyplot as plt
_df_13.plot(kind='scatter', x='index', y='Frequencies', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from matplotlib import pyplot as plt
items_table['Frequencies'].plot(kind='line', figsize=(8, 4), title='Frequencies')
plt.gca().spines[['top', 'right']].set_visible(False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from matplotlib import pyplot as plt
items_table['Frequencies'].plot(kind='hist', bins=20, title='Frequencies')
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
items_table.plot(kind='hist', bins=20, title='Frequencies of Items')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
items_table.sort_values('Frequencies', ascending=False).head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      Names  Frequencies
# 6   Coffee         5471
# 0    Bread         3325
# 9      Tea         1435
# 23    Cake         1025
# 7   Pastry          856
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_18['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['Frequencies'].plot(kind='hist', bins=20, title='Frequencies')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_20.groupby('Names').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_21.plot(kind='scatter', x='index', y='Frequencies', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_22['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['Frequencies'].plot(kind='line', figsize=(8, 4), title='Frequencies')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_24['Names'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_24, x='index', y='Names', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['Names'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='Frequencies', y='Names', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
items_table.plot.bar(y='Frequencies', x='Names', figsize=(14, 8))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: xlabel='Names'>

# %%
items_table.sort_values('Frequencies', ascending=False).head(20).\
    plot.bar(y='Frequencies', x='Names', figsize=(12, 8))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: xlabel='Names'>

# %%
bread_basket_data['Transaction'].describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# count    20507.000000
# mean      4976.202370
# std       2796.203001
# min          1.000000
# 25%       2552.000000
# 50%       5137.000000
# 75%       7357.000000
# max       9684.000000
# Name: Transaction, dtype: float64

# %%
bread_basket_data = bread_basket_data.groupby('Transaction').agg(','.join).reset_index()

bread_basket_data = bread_basket_data.drop(['Date', 'Time'], axis=1)
bread_basket_data.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Transaction                         Item
# 0            1                        Bread
# 1            2    Scandinavian,Scandinavian
# 2            3    Hot chocolate,Jam,Cookies
# 3            4                       Muffin
# 4            5          Coffee,Pastry,Bread
# 5            6      Medialuna,Pastry,Muffin
# 6            7  Medialuna,Pastry,Coffee,Tea
# 7            8                 Pastry,Bread
# 8            9                 Bread,Muffin
# 9           10       Scandinavian,Medialuna

# %%
bread_basket_data.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (9465, 2)

# %%
items_data = bread_basket_data['Item']

items_data.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0                          Bread
# 1      Scandinavian,Scandinavian
# 2      Hot chocolate,Jam,Cookies
# 3                         Muffin
# 4            Coffee,Pastry,Bread
# 5        Medialuna,Pastry,Muffin
# 6    Medialuna,Pastry,Coffee,Tea
# 7                   Pastry,Bread
# 8                   Bread,Muffin
# 9         Scandinavian,Medialuna
# Name: Item, dtype: object

# %%
items_list = [item.split(',') for item in items_data]

items_list_df = pd.DataFrame({'Items': items_list})

items_list_df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                               Items
# 0                           [Bread]
# 1      [Scandinavian, Scandinavian]
# 2     [Hot chocolate, Jam, Cookies]
# 3                          [Muffin]
# 4           [Coffee, Pastry, Bread]
# 5       [Medialuna, Pastry, Muffin]
# 6  [Medialuna, Pastry, Coffee, Tea]
# 7                   [Pastry, Bread]
# 8                   [Bread, Muffin]
# 9         [Scandinavian, Medialuna]

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

transencoder = TransactionEncoder()

transencoder_array = transencoder.fit(items_list).transform(items_list)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
encoded_df = pd.DataFrame(transencoder_array, columns=transencoder.columns_)

encoded_df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Adjustment  Afternoon with the baker  Alfajores  Argentina Night  Art Tray  \
# 0       False                     False      False            False     False
# 1       False                     False      False            False     False
# 2       False                     False      False            False     False
# 3       False                     False      False            False     False
# 4       False                     False      False            False     False
# 5       False                     False      False            False     False
# 6       False                     False      False            False     False
# 7       False                     False      False            False     False
# 8       False                     False      False            False     False
# 9       False                     False      False            False     False
#
#    Bacon  Baguette  Bakewell  Bare Popcorn  Basket  ...  The BART  The Nomad  \
# 0  False     False     False         False   False  ...     False      False
# 1  False     False     False         False   False  ...     False      False
# 2  False     False     False         False   False  ...     False      False
# 3  False     False     False         False   False  ...     False      False
# 4  False     False     False         False   False  ...     False      False
# 5  False     False     False         False   False  ...     False      False
# 6  False     False     False         False   False  ...     False      False
# 7  False     False     False         False   False  ...     False      False
# 8  False     False     False         False   False  ...     False      False
# 9  False     False     False         False   False  ...     False      False
#
#    Tiffin  Toast  Truffles  Tshirt  Valentine's card  Vegan Feast  \
# 0   False  False     False   False             False        False
# 1   False  False     False   False             False        False
# 2   False  False     False   False             False        False
# 3   False  False     False   False             False        False
# 4   False  False     False   False             False        False
# 5   False  False     False   False             False        False
# 6   False  False     False   False             False        False
# 7   False  False     False   False             False        False
# 8   False  False     False   False             False        False
# 9   False  False     False   False             False        False
#
#    Vegan mincepie  Victorian Sponge
# 0           False             False
# 1           False             False
# 2           False             False
# 3           False             False
# 4           False             False
# 5           False             False
# 6           False             False
# 7           False             False
# 8           False             False
# 9           False             False
#
# [10 rows x 94 columns]

# %%
item_support_df = apriori(encoded_df, min_support=0.01, use_colnames=True)

item_support_df.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (61, 2)

# %%
item_support_df.sample(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      support             itemsets
# 25  0.018172     (Spanish Brunch)
# 30  0.010354   (Alfajores, Bread)
# 32  0.010777     (Brownie, Bread)
# 60  0.010037  (Coffee, Cake, Tea)
# 37  0.016904   (Medialuna, Bread)
# 34  0.090016      (Bread, Coffee)
# 2   0.327205              (Bread)
# 39  0.017010    (Sandwich, Bread)
# 20  0.010460              (Salad)
# 4   0.103856               (Cake)

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(item_support_df,
                          metric='confidence', min_threshold=0.1)

rules.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (44, 10)

# %%
rules.sample(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          antecedents      consequents  antecedent support  consequent support  \
# 38  (Pastry, Coffee)          (Bread)            0.047544            0.327205
# 22       (Medialuna)         (Coffee)            0.061807            0.478394
# 16   (Hot chocolate)           (Cake)            0.058320            0.103856
# 26           (Scone)         (Coffee)            0.034548            0.478394
# 40          (Pastry)  (Bread, Coffee)            0.086107            0.090016
# 37   (Bread, Coffee)         (Pastry)            0.090016            0.086107
# 3             (Cake)          (Bread)            0.103856            0.327205
# 20   (Hot chocolate)         (Coffee)            0.058320            0.478394
# 5           (Coffee)          (Bread)            0.478394            0.327205
# 17            (Cake)            (Tea)            0.103856            0.142631
#
#      support  confidence      lift  leverage  conviction  zhangs_metric
# 38  0.011199    0.235556  0.719901 -0.004357    0.880109      -0.290026
# 22  0.035182    0.569231  1.189878  0.005614    1.210871       0.170091
# 16  0.011410    0.195652  1.883874  0.005354    1.114125       0.498236
# 26  0.018067    0.522936  1.093107  0.001539    1.093366       0.088224
# 40  0.011199    0.130061  1.444872  0.003448    1.046033       0.336907
# 37  0.011199    0.124413  1.444872  0.003448    1.043749       0.338354
# 3   0.023349    0.224822  0.687097 -0.010633    0.867923      -0.336947
# 20  0.029583    0.507246  1.060311  0.001683    1.058553       0.060403
# 5   0.090016    0.188163  0.575059 -0.066517    0.828731      -0.586210
# 17  0.023772    0.228891  1.604781  0.008959    1.111865       0.420538

# %%
rules.sort_values('confidence', ascending=False).head(15)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          antecedents consequents  antecedent support  consequent support  \
# 31           (Toast)    (Coffee)            0.033597            0.478394
# 28  (Spanish Brunch)    (Coffee)            0.018172            0.478394
# 22       (Medialuna)    (Coffee)            0.061807            0.478394
# 24          (Pastry)    (Coffee)            0.086107            0.478394
# 1        (Alfajores)    (Coffee)            0.036344            0.478394
# 21           (Juice)    (Coffee)            0.038563            0.478394
# 25        (Sandwich)    (Coffee)            0.071844            0.478394
# 13            (Cake)    (Coffee)            0.103856            0.478394
# 26           (Scone)    (Coffee)            0.034548            0.478394
# 19         (Cookies)    (Coffee)            0.054411            0.478394
# 20   (Hot chocolate)    (Coffee)            0.058320            0.478394
# 12         (Brownie)    (Coffee)            0.040042            0.478394
# 23          (Muffin)    (Coffee)            0.038457            0.478394
# 27            (Soup)    (Coffee)            0.034443            0.478394
# 34     (Cake, Bread)    (Coffee)            0.023349            0.478394
#
#      support  confidence      lift  leverage  conviction  zhangs_metric
# 31  0.023666    0.704403  1.472431  0.007593    1.764582       0.332006
# 28  0.010882    0.598837  1.251766  0.002189    1.300235       0.204851
# 22  0.035182    0.569231  1.189878  0.005614    1.210871       0.170091
# 24  0.047544    0.552147  1.154168  0.006351    1.164682       0.146161
# 1   0.019651    0.540698  1.130235  0.002264    1.135648       0.119574
# 21  0.020602    0.534247  1.116750  0.002154    1.119919       0.108738
# 25  0.038246    0.532353  1.112792  0.003877    1.115384       0.109205
# 13  0.054728    0.526958  1.101515  0.005044    1.102664       0.102840
# 26  0.018067    0.522936  1.093107  0.001539    1.093366       0.088224
# 19  0.028209    0.518447  1.083723  0.002179    1.083174       0.081700
# 20  0.029583    0.507246  1.060311  0.001683    1.058553       0.060403
# 12  0.019651    0.490765  1.025860  0.000495    1.024293       0.026259
# 23  0.018806    0.489011  1.022193  0.000408    1.020777       0.022579
# 27  0.015848    0.460123  0.961807 -0.000629    0.966156      -0.039502
# 34  0.010037    0.429864  0.898557 -0.001133    0.914880      -0.103617

# %%
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))

rules.sample(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          antecedents      consequents  antecedent support  consequent support  \
# 27            (Soup)         (Coffee)            0.034443            0.478394
# 13            (Cake)         (Coffee)            0.103856            0.478394
# 14          (Coffee)           (Cake)            0.478394            0.103856
# 11             (Tea)          (Bread)            0.142631            0.327205
# 35    (Cake, Coffee)          (Bread)            0.054728            0.327205
# 5           (Coffee)          (Bread)            0.478394            0.327205
# 12         (Brownie)         (Coffee)            0.040042            0.478394
# 2          (Brownie)          (Bread)            0.040042            0.327205
# 10        (Sandwich)          (Bread)            0.071844            0.327205
# 6          (Cookies)          (Bread)            0.054411            0.327205
# 26           (Scone)         (Coffee)            0.034548            0.478394
# 40          (Pastry)  (Bread, Coffee)            0.086107            0.090016
# 19         (Cookies)         (Coffee)            0.054411            0.478394
# 22       (Medialuna)         (Coffee)            0.061807            0.478394
# 31           (Toast)         (Coffee)            0.033597            0.478394
# 8        (Medialuna)          (Bread)            0.061807            0.327205
# 4            (Bread)         (Coffee)            0.327205            0.478394
# 1        (Alfajores)         (Coffee)            0.036344            0.478394
# 23          (Muffin)         (Coffee)            0.038457            0.478394
# 38  (Pastry, Coffee)          (Bread)            0.047544            0.327205
#
#      support  confidence      lift  leverage  conviction  zhangs_metric  \
# 27  0.015848    0.460123  0.961807 -0.000629    0.966156      -0.039502
# 13  0.054728    0.526958  1.101515  0.005044    1.102664       0.102840
# 14  0.054728    0.114399  1.101515  0.005044    1.011905       0.176684
# 11  0.028104    0.197037  0.602181 -0.018566    0.837890      -0.435198
# 35  0.010037    0.183398  0.560497 -0.007870    0.823895      -0.453411
# 5   0.090016    0.188163  0.575059 -0.066517    0.828731      -0.586210
# 12  0.019651    0.490765  1.025860  0.000495    1.024293       0.026259
# 2   0.010777    0.269129  0.822508 -0.002326    0.920538      -0.183536
# 10  0.017010    0.236765  0.723596 -0.006498    0.881503      -0.291561
# 6   0.014474    0.266019  0.813004 -0.003329    0.916638      -0.195651
# 26  0.018067    0.522936  1.093107  0.001539    1.093366       0.088224
# 40  0.011199    0.130061  1.444872  0.003448    1.046033       0.336907
# 19  0.028209    0.518447  1.083723  0.002179    1.083174       0.081700
# 22  0.035182    0.569231  1.189878  0.005614    1.210871       0.170091
# 31  0.023666    0.704403  1.472431  0.007593    1.764582       0.332006
# 8   0.016904    0.273504  0.835879 -0.003319    0.926082      -0.173062
# 4   0.090016    0.275105  0.575059 -0.066517    0.719561      -0.523431
# 1   0.019651    0.540698  1.130235  0.002264    1.135648       0.119574
# 23  0.018806    0.489011  1.022193  0.000408    1.020777       0.022579
# 38  0.011199    0.235556  0.719901 -0.004357    0.880109      -0.290026
#
#     antecedent_len
# 27               1
# 13               1
# 14               1
# 11               1
# 35               2
# 5                1
# 12               1
# 2                1
# 10               1
# 6                1
# 26               1
# 40               1
# 19               1
# 22               1
# 31               1
# 8                1
# 4                1
# 1                1
# 23               1
# 38               2

# %%
rules[rules['antecedents'] == {'Juice'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    antecedents consequents  antecedent support  consequent support   support  \
# 21     (Juice)    (Coffee)            0.038563            0.478394  0.020602
#
#     confidence     lift  leverage  conviction  zhangs_metric  antecedent_len
# 21    0.534247  1.11675  0.002154    1.119919       0.108738               1

# %%
rules[rules['antecedents'] == {'Cake'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    antecedents      consequents  antecedent support  consequent support  \
# 3       (Cake)          (Bread)            0.103856            0.327205
# 13      (Cake)         (Coffee)            0.103856            0.478394
# 15      (Cake)  (Hot chocolate)            0.103856            0.058320
# 17      (Cake)            (Tea)            0.103856            0.142631
#
#      support  confidence      lift  leverage  conviction  zhangs_metric  \
# 3   0.023349    0.224822  0.687097 -0.010633    0.867923      -0.336947
# 13  0.054728    0.526958  1.101515  0.005044    1.102664       0.102840
# 15  0.011410    0.109868  1.883874  0.005354    1.057910       0.523553
# 17  0.023772    0.228891  1.604781  0.008959    1.111865       0.420538
#
#     antecedent_len
# 3                1
# 13               1
# 15               1
# 17               1

# %%
rules[rules['antecedents'] == {'Sandwich'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    antecedents consequents  antecedent support  consequent support   support  \
# 10  (Sandwich)     (Bread)            0.071844            0.327205  0.017010
# 25  (Sandwich)    (Coffee)            0.071844            0.478394  0.038246
# 32  (Sandwich)       (Tea)            0.071844            0.142631  0.014369
#
#     confidence      lift  leverage  conviction  zhangs_metric  antecedent_len
# 10    0.236765  0.723596 -0.006498    0.881503      -0.291561               1
# 25    0.532353  1.112792  0.003877    1.115384       0.109205               1
# 32    0.200000  1.402222  0.004122    1.071712       0.309050               1

# %%
rules[rules['antecedents'] == {'Muffin'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    antecedents consequents  antecedent support  consequent support   support  \
# 23    (Muffin)    (Coffee)            0.038457            0.478394  0.018806
#
#     confidence      lift  leverage  conviction  zhangs_metric  antecedent_len
# 23    0.489011  1.022193  0.000408    1.020777       0.022579               1

# %%
rules[rules['antecedents'] == {'Toast'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    antecedents consequents  antecedent support  consequent support   support  \
# 31     (Toast)    (Coffee)            0.033597            0.478394  0.023666
#
#     confidence      lift  leverage  conviction  zhangs_metric  antecedent_len
# 31    0.704403  1.472431  0.007593    1.764582       0.332006               1

# %%
rules[rules['antecedents'] == {'Bread'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   antecedents consequents  antecedent support  consequent support   support  \
# 4     (Bread)    (Coffee)            0.327205            0.478394  0.090016
#
#    confidence      lift  leverage  conviction  zhangs_metric  antecedent_len
# 4    0.275105  0.575059 -0.066517    0.719561      -0.523431               1

# %%
rules[rules['antecedents'] == {'Coffee'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    antecedents consequents  antecedent support  consequent support   support  \
# 5     (Coffee)     (Bread)            0.478394            0.327205  0.090016
# 14    (Coffee)      (Cake)            0.478394            0.103856  0.054728
# 30    (Coffee)       (Tea)            0.478394            0.142631  0.049868
#
#     confidence      lift  leverage  conviction  zhangs_metric  antecedent_len
# 5     0.188163  0.575059 -0.066517    0.828731      -0.586210               1
# 14    0.114399  1.101515  0.005044    1.011905       0.176684               1
# 30    0.104240  0.730840 -0.018366    0.957142      -0.413856               1

# %%
rules[rules['antecedents'] == {'Hot chocolate'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         antecedents consequents  antecedent support  consequent support  \
# 7   (Hot chocolate)     (Bread)             0.05832            0.327205
# 16  (Hot chocolate)      (Cake)             0.05832            0.103856
# 20  (Hot chocolate)    (Coffee)             0.05832            0.478394
#
#      support  confidence      lift  leverage  conviction  zhangs_metric  \
# 7   0.013418    0.230072  0.703144 -0.005665    0.873841      -0.309550
# 16  0.011410    0.195652  1.883874  0.005354    1.114125       0.498236
# 20  0.029583    0.507246  1.060311  0.001683    1.058553       0.060403
#
#     antecedent_len
# 7                1
# 16               1
# 20               1

# %%
rules[rules['antecedents'] == {'Tea'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    antecedents consequents  antecedent support  consequent support   support  \
# 11       (Tea)     (Bread)            0.142631            0.327205  0.028104
# 18       (Tea)      (Cake)            0.142631            0.103856  0.023772
# 29       (Tea)    (Coffee)            0.142631            0.478394  0.049868
# 33       (Tea)  (Sandwich)            0.142631            0.071844  0.014369
#
#     confidence      lift  leverage  conviction  zhangs_metric  antecedent_len
# 11    0.197037  0.602181 -0.018566    0.837890      -0.435198               1
# 18    0.166667  1.604781  0.008959    1.075372       0.439556               1
# 29    0.349630  0.730840 -0.018366    0.802014      -0.300482               1
# 33    0.100741  1.402222  0.004122    1.032134       0.334566               1

# %%
rules[rules['antecedents'] == {'Cookies'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    antecedents consequents  antecedent support  consequent support   support  \
# 6    (Cookies)     (Bread)            0.054411            0.327205  0.014474
# 19   (Cookies)    (Coffee)            0.054411            0.478394  0.028209
#
#     confidence      lift  leverage  conviction  zhangs_metric  antecedent_len
# 6     0.266019  0.813004 -0.003329    0.916638      -0.195651               1
# 19    0.518447  1.083723  0.002179    1.083174       0.081700               1

# %%
rules[rules['antecedents'] == {'Pastry'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    antecedents      consequents  antecedent support  consequent support  \
# 9     (Pastry)          (Bread)            0.086107            0.327205
# 24    (Pastry)         (Coffee)            0.086107            0.478394
# 40    (Pastry)  (Bread, Coffee)            0.086107            0.090016
#
#      support  confidence      lift  leverage  conviction  zhangs_metric  \
# 9   0.029160    0.338650  1.034977  0.000985    1.017305       0.036980
# 24  0.047544    0.552147  1.154168  0.006351    1.164682       0.146161
# 40  0.011199    0.130061  1.444872  0.003448    1.046033       0.336907
#
#     antecedent_len
# 9                1
# 24               1
# 40               1

# %%
rules[rules['antecedents'] == {'Medialuna'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     antecedents consequents  antecedent support  consequent support   support  \
# 8   (Medialuna)     (Bread)            0.061807            0.327205  0.016904
# 22  (Medialuna)    (Coffee)            0.061807            0.478394  0.035182
#
#     confidence      lift  leverage  conviction  zhangs_metric  antecedent_len
# 8     0.273504  0.835879 -0.003319    0.926082      -0.173062               1
# 22    0.569231  1.189878  0.005614    1.210871       0.170091               1

# %%
rules[rules['antecedents'] == {'Mineral water'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric, antecedent_len]
# Index: []

# %%
rules[rules['antecedents'] == {'Coke'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric, antecedent_len]
# Index: []

# %%
rules[rules['antecedents'] == {'Scone'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    antecedents consequents  antecedent support  consequent support   support  \
# 26     (Scone)    (Coffee)            0.034548            0.478394  0.018067
#
#     confidence      lift  leverage  conviction  zhangs_metric  antecedent_len
# 26    0.522936  1.093107  0.001539    1.093366       0.088224               1

# %%
rules[rules['antecedents'] == {'Chimichurri oil'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric, antecedent_len]
# Index: []

# %%
rules[rules['antecedents'] == {'Eggs'}]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric, antecedent_len]
# Index: []
